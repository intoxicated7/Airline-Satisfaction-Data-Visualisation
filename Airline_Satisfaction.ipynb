# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/10K_Airline Passenger Satisfaction - V4.csv')

# %%
print('Total passangers', satisfaction.count())
sns.countplot(x=satisfaction)

plt.suptitle('Overall Satisfaction')
plt.show()
# Out:
# Total passangers 9342

# %%
age = df['Age']
satisfaction = df['Satisfaction Rating']

sns.relplot(
    x=age,
    y=satisfaction,
    kind='line',
    color='blue', height=4
)

plt.suptitle('Satisfaction by Passanger Age')
plt.subplots_adjust(top=0.9)
plt.show()

# %%
gender = df['Gender']

sns.countplot(x=gender, hue=satisfaction)

plt.suptitle('Satisfaction by Passanger Gender')
plt.show()

# %%
travel_class = df['Class']

sns.countplot(x=travel_class, hue=satisfaction)

plt.suptitle('Satisfaction by Passanger Class')
plt.show()

# %%
counts = df['Type of Travel'].value_counts()

business_count = counts.get('Business')
personal_count = counts.get('Personal')

plt.pie(
    [business_count, personal_count],
    labels=['Business', 'Personal'],
    wedgeprops=dict(width=0.5))

plt.suptitle('Purpose of Travel')
plt.show()
